# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
company = ['GOOGL','AMZN','MSFT','FB']
revenue = [90, 136, 89, 27]

# %%
import numpy as np

# %%
xpos = np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.bar(xpos,revenue, label="Revenue")
plt.xticks(xpos,company)
# Out:
# ([<matplotlib.axis.XTick at 0x19b4bdfc640>,
#   <matplotlib.axis.XTick at 0x19b4bdfc610>,
#   <matplotlib.axis.XTick at 0x19b4bdd6400>,
#   <matplotlib.axis.XTick at 0x19b4be52820>],
#  [Text(0, 0, 'GOOGL'),
#   Text(1, 0, 'AMZN'),
#   Text(2, 0, 'MSFT'),
#   Text(3, 0, 'FB')])

# %%
plt.bar(xpos,revenue, label="Revenue")
plt.xticks(xpos,company)
plt.xlabel('Revenue')
plt.ylabel('Tech Companies')
plt.legend()

# %%
profit=[40,2,34,12]

# %%
plt.bar(xpos-0.2,revenue, width=0.4, label="Revenue")
plt.bar(xpos+0.2,profit, width=0.4, label="Profit")

plt.xticks(xpos,company)
plt.xlabel('Revenue')
plt.ylabel('Tech Companies')
plt.legend()

# %%
plt.barh(xpos,revenue, label="Revenue")

plt.yticks(xpos,company)
plt.xlabel('Revenue')
plt.ylabel('Tech Companies')
plt.legend()
